# %%
from google.colab import drive

drive.mount('/content/gdrive')

import pandas as pd
PATH = 'gdrive/My Drive/Датасеты/'
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %%
df = pd.read_excel(PATH + 'Мероприятия/Мероприятия.xlsx')

# %%
df.head()
# Out:
#      id  ...                                  Целевая аудитория
# 0     5  ...                                                NaN
# 1    12  ...          работающая молодежь, взрослые, пенсионеры
# 2  3179  ...  школьники, работающая молодежь, студенческая м...
# 3   486  ...               дети дошкольного возраста, школьники
# 4  2100  ...  дети дошкольного возраста, школьники, работающ...
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (41074, 25)

# %%
df['Целевая аудитория'].unique()
# Out:
# array([nan, 'работающая молодежь, взрослые, пенсионеры',
#        'школьники, работающая молодежь, студенческая молодежь, взрослые, пенсионеры',
#        'дети дошкольного возраста, школьники',
#        'дети дошкольного возраста, школьники, работающая молодежь, студенческая молодежь, взрослые, пенсионеры',
#        'дети дошкольного возраста, школьники, работающая молодежь, студенческая молодежь, взрослые, другое, пенсионеры',
#        'работающая молодежь, студенческая молодежь, взрослые',
#        'работающая молодежь, студенческая молодежь, взрослые, пенсионеры',
#        'дети дошкольного возраста, школьники, студенческая молодежь',
#        'дети дошкольного возраста, школьники, взрослые',
#        'дети дошкольного возраста, школьники, взрослые, пенсионеры',
#        'дети дошкольного возраста, взрослые', 'дети дошкольного возраста',
#        'школьники', 'взрослые, пенсионеры', 'школьники, взрослые',
#        'школьники, работающая молодежь, студенческая молодежь',
# ...

# %%
df[(df['Тип мероприятия'] == 'выставка') & (df['Направленность мероприятия'] == 'культурно-досуговое') & (df['Округ'] == 'Южный административный округ')].head(5).to_json('activities_recommend.json')

# %%
act_types = df['Тип мероприятия'].dropna().unique()
act_direct = df['Направленность мероприятия'].dropna().unique()

act_direct = [g.split(';') for g in act_direct]
b = []
for g in act_direct:
    for i in g:
        b.append(i.strip())

act_direct = list(b)

# %%
import json
with open('recom_user_353401.json') as json_file:
    data1 = json.load(json_file)

# %%
data1 = dict(data1)

# %%
def list_diff(list1,list2):
    
    list_difference = []
    for item in list1:
        if item not in list2:
            print(item)
            list_difference.append(item)
    return list_difference

# %%
class MyList(list):
    def __hash__(self):
        return sum([len(s) for s in self])

# %%
un_authors_list = []

for typ in ['by_genre', 'by_author', 'by_serie']:
    keys = data1['recommendations'][typ].keys()

    for key in keys:
        for book in data1['recommendations'][typ][key]['list_of_recommendations']:
            un_authors_list.append(MyList([book['author'], book['name']]))
        print(data1['recommendations'][typ][key]['list_of_recommendations'], ',')

print(len(un_authors_list))
print(len(list(set(un_authors_list))))
# Out:
# [{'author': 'Круз Андрей', 'name': 'Рейтар', 'genre': 'Художественная литература', 'year': '2013'}, {'author': 'Петров Василий Петрович', 'name': 'Оды ; Письма в стихах ; Разные стихотворения', 'genre': 'Художественная литература', 'year': '2016'}, {'author': 'Свечин Николай', 'name': 'Завещание Аввакума. Происшествия из службы сыщика Алексея Лыкова и его друзей', 'genre': 'Художественная литература', 'year': '2014'}, {'author': 'Буль Пьер', 'name': 'Планета обезьян', 'genre': 'Художественная литература', 'year': '2017'}, {'author': 'Сафарли Эльчин', 'name': 'Когда я вернусь, будь дома', 'genre': 'Художественная литература', 'year': '2017'}] ,
# ...

# %%
un_authors_list
# Out:
# [('Круз Андрей', 'Рейтар'),
#  ('Петров Василий Петрович', 'Оды ; Письма в стихах ; Разные стихотворения'),
#  ('Свечин Николай',
#   'Завещание Аввакума. Происшествия из службы сыщика Алексея Лыкова и его друзей'),
#  ('Буль Пьер', 'Планета обезьян'),
#  ('Сафарли Эльчин', 'Когда я вернусь, будь дома'),
#  ('Ярошевская Анна', 'Татьяна Самойлова'),
#  ('Депардье Жерар', 'Такие дела…'),
#  ('Долин Антон Владимирович', 'Оттенки русского'),
#  ('Филимонов Виктор Петрович', 'Андрей Кончаловский. Никто не знает...'),
#  ('Захарчук Михаил Александрович', 'Алексей Баталов. Жизнь. Игра. Трагедия'),
#  ('Джойс Бренда', 'Смертельные обеты'),
#  ('Сагг Зои', 'Девушка online в турне'),
#  ('Кинг Стивен', 'Черный дом'),
#  ('Сафарли Эльчин', 'Когда я без тебя...'),
#  ('Пьетри Анни', 'Тайное поручение короля'),
#  ('Несбе Ю.', 'Кровь на снегу'),
#  ('Лителл Джейн', 'Отнять всё'),
#  ('Кристи Агата', 'Немезида'),
#  ('Стаут Рекс', 'Горная кошка'),
#  ('Робертс Нора', 'Охота на бабочек'),
# ...

# %%
import collections

au_to_del = [[item, count] for item, count in collections.Counter(un_authors_list).items() if count > 1]

# %%
au_to_del
# Out:
# [[['Иванов Алексей Викторович', 'Дебри'], 2],
#  [['Иванов Алексей Викторович', 'Ненастье'], 3],
#  [['Иванов Алексей Викторович', 'Тобол. Мало избранных'], 2],
#  [['Иванов Алексей Викторович', 'Ёбург'], 2],
#  [['Хоуг Тэми', 'Ночные грехи'], 2],
#  [['Снегирев Александр', 'Как же ее звали?..'], 2],
#  [['Снегирев Александр', 'Как же её звали?..'], 2],
#  [['Снегирев Александр', 'Я намерен хорошо провести этот вечер'], 2],
#  [['Снегирев Александр', 'Как мы бомбили Америку'], 2],
#  [['Снегирев Александр', 'Вера'], 2]]

# %%
lists = [[{'author': 'Круз Андрей', 'name': 'Рейтар', 'genre': 'Художественная литература', 'year': '2013'}, {'author': 'Петров Василий Петрович', 'name': 'Оды ; Письма в стихах ; Разные стихотворения', 'genre': 'Художественная литература', 'year': '2016'}, {'author': 'Свечин Николай', 'name': 'Завещание Аввакума. Происшествия из службы сыщика Алексея Лыкова и его друзей', 'genre': 'Художественная литература', 'year': '2014'}, {'author': 'Буль Пьер', 'name': 'Планета обезьян', 'genre': 'Художественная литература', 'year': '2017'}, {'author': 'Сафарли Эльчин', 'name': 'Когда я вернусь, будь дома', 'genre': 'Художественная литература', 'year': '2017'}] ,
[{'author': 'Ярошевская Анна', 'name': 'Татьяна Самойлова', 'genre': 'Художественно-игровое кино', 'year': '2014'}, {'author': 'Депардье Жерар', 'name': 'Такие дела…', 'genre': 'Художественно-игровое кино', 'year': '2015'}, {'author': 'Долин Антон Владимирович', 'name': 'Оттенки русского', 'genre': 'Художественно-игровое кино', 'year': '2017'}, {'author': 'Филимонов Виктор Петрович', 'name': 'Андрей Кончаловский. Никто не знает...', 'genre': 'Художественно-игровое кино', 'year': '2017'}, {'author': 'Захарчук Михаил Александрович', 'name': 'Алексей Баталов. Жизнь. Игра. Трагедия', 'genre': 'Художественно-игровое кино', 'year': '2018'}] ,
[{'author': 'Джойс Бренда', 'name': 'Смертельные обеты', 'genre': 'Зарубежная проза', 'year': '2013'}, {'author': 'Сагг Зои', 'name': 'Девушка online в турне', 'genre': 'Зарубежная проза', 'year': '2016'}, {'author': 'Кинг Стивен', 'name': 'Черный дом', 'genre': 'Зарубежная проза', 'year': '2017'}, {'author': 'Сафарли Эльчин', 'name': 'Когда я без тебя...', 'genre': 'Зарубежная проза', 'year': '2015'}, {'author': 'Пьетри Анни', 'name': 'Тайное поручение короля', 'genre': 'Зарубежная проза', 'year': '2013'}] ,
[{'author': 'Несбе Ю.', 'name': 'Кровь на снегу', 'genre': 'Зарубежный детектив', 'year': '2015'}, {'author': 'Лителл Джейн', 'name': 'Отнять всё', 'genre': 'Зарубежный детектив', 'year': '2016'}, {'author': 'Кристи Агата', 'name': 'Немезида', 'genre': 'Зарубежный детектив', 'year': '2013'}, {'author': 'Стаут Рекс', 'name': 'Горная кошка', 'genre': 'Зарубежный детектив', 'year': '2015'}, {'author': 'Робертс Нора', 'name': 'Охота на бабочек', 'genre': 'Зарубежный детектив', 'year': '2017'}] ,
[{'author': 'Дэвид-Фокс Майкл', 'name': 'Витрины великого эксперимента. Культурная дипломатия Советского Союза и его западные гости, 1921-1941 годы', 'genre': 'История России', 'year': '2015'}, {'author': 'Гордин Яков Аркадьевич', 'name': 'Мятеж реформаторов. Когда решалась судьба России', 'genre': 'История России', 'year': '2015'}, {'author': 'Глушкова Вера Георгиевна', 'name': 'Новгородская земля', 'genre': 'История России', 'year': '2016'}, {'author': 'Глушкова Вера Георгиевна', 'name': 'Костромская земля', 'genre': 'История России', 'year': '2016'}, {'author': 'Бондаренко Вячеслав Васильевич', 'name': 'Герои Первой мировой', 'genre': 'История России', 'year': '2014'}] ,
[{'author': 'Максимов Андрей Маркович', 'name': 'Общение : в поисках общего', 'genre': 'Социальная психология', 'year': '2015'}, {'author': 'Прокопенко Игорь Станиславович', 'name': 'Тайны мужчины и женщины', 'genre': 'Социальная психология', 'year': '2017'}, {'author': 'Энглер Брэнди', 'name': 'Мужчины на моей кушетке', 'genre': 'Социальная психология', 'year': '2013'}, {'author': 'Зберовский А. В.', 'name': 'Грабли для молодоженов, или Учимся на чужих семейных ошибках', 'genre': 'Социальная психология', 'year': '2010'}, {'author': 'Берн Эрик', 'name': 'Введение в психиатрию и психоанализ для непосвященных', 'genre': 'Социальная психология', 'year': '2017'}] ,
[{'author': 'Иванов Алексей Викторович', 'name': 'Дебри', 'genre': 'Художественная литература ; Российская проза', 'year': '2017'}, {'author': 'Иванов Алексей Викторович', 'name': 'Ненастье', 'genre': 'Художественная литература', 'year': '2016'}, {'author': 'Иванов Алексей Викторович', 'name': 'Тобол. Мало избранных', 'genre': 'Художественная литература ; Проза', 'year': '2018'}, {'author': 'Иванов Алексей Викторович', 'name': 'Ёбург', 'genre': 'Художественная литература ; Проза', 'year': '2018'}, {'author': 'Иванов Алексей Викторович', 'name': 'Ебург', 'genre': 'Художественная литература', 'year': '2015'}] ,
[{'author': 'Хоуг Тэми', 'name': 'Ночные грехи', 'genre': 'Художественная литература ; Детектив', 'year': '2013'}] ,
[{'author': 'Гореславская Нелли Борисовна', 'name': 'Татьяна Доронина. Еще раз про любовь.', 'genre': 'Художественно-игровое кино', 'year': '2016'}] ,
[] ,
[{'author': 'Снегирев Александр', 'name': 'Как же ее звали?..', 'genre': 'Художественная литература', 'year': '2016'}, {'author': 'Снегирев Александр', 'name': 'Как же её звали?..', 'genre': 'Художественная литература', 'year': '2015'}, {'author': 'Снегирев Александр', 'name': 'Я намерен хорошо провести этот вечер', 'genre': 'Художественная литература', 'year': '2016'}, {'author': 'Снегирев Александр', 'name': 'Как мы бомбили Америку', 'genre': 'Художественная литература', 'year': '2015'}, {'author': 'Снегирев Александр', 'name': 'Вера', 'genre': 'Художественная литература', 'year': '2016'}] ,
[] ,
[] ,
[{'author': 'Шелдон Сидни', 'name': 'Расколотые сны', 'genre': 'Художественная литература', 'year': '2016'}, {'author': 'Шелдон Сидни', 'name': 'Звезды светят вниз', 'genre': 'Художественная литература', 'year': '2017'}, {'author': 'Шелдон Сидни', 'name': 'Тонкий расчет', 'genre': 'Художественная литература', 'year': '2017'}, {'author': 'Шелдон Сидни', 'name': 'Пески времени', 'genre': 'Художественная литература', 'year': '2017'}, {'author': 'Шелдон Сидни', 'name': 'Рухнувшие небеса', 'genre': 'Художественная литература', 'year': '2016'}] ,
[] ,
[] ,
[] ,
[{'author': 'Иванов Алексей Викторович', 'name': 'Дебри', 'genre': 'Художественная литература ; Российская проза', 'year': '2017'}, {'author': 'Иванов Алексей Викторович', 'name': 'Ненастье', 'genre': 'Художественная литература', 'year': '2016'}, {'author': 'Иванов Алексей Викторович', 'name': 'Тобол. Мало избранных', 'genre': 'Художественная литература ; Проза', 'year': '2018'}, {'author': 'Иванов Алексей Викторович', 'name': 'Ёбург', 'genre': 'Художественная литература ; Проза', 'year': '2018'}, {'author': 'Иванов Алексей Викторович', 'name': 'Ненастье', 'genre': 'Художественная литература', 'year': '2015'}] ,
[{'author': 'Хоуг Тэми', 'name': 'Ночные грехи', 'genre': 'Художественная литература ; Детектив', 'year': '2013'}] ,
[{'author': 'Мультатули Петр Валентинович', 'name': 'Император Николай II. Человек и монарх', 'genre': 'История в целом. Всемирная история', 'year': '2016'}, {'author': 'Мультатули Петр Валентинович', 'name': 'Император Николай II мученик', 'genre': 'История России', 'year': '2018'}, {'author': 'Шахмагонов Николай Федорович', 'name': 'Екатерина Великая', 'genre': 'История России', 'year': '2019'}] ,
[{'author': 'Снегирев Александр', 'name': 'Как же ее звали?..', 'genre': 'Художественная литература', 'year': '2016'}, {'author': 'Снегирев Александр', 'name': 'Как же её звали?..', 'genre': 'Художественная литература', 'year': '2015'}, {'author': 'Снегирев Александр', 'name': 'Я намерен хорошо провести этот вечер', 'genre': 'Художественная литература', 'year': '2016'}, {'author': 'Снегирев Александр', 'name': 'Как мы бомбили Америку', 'genre': 'Художественная литература', 'year': '2015'}, {'author': 'Снегирев Александр', 'name': 'Вера', 'genre': 'Художественная литература', 'year': '2016'}] ,
[] ,
[] ,
[{'author': 'Кинг Стивен', 'name': 'Мобильник', 'genre': 'Художественная литература', 'year': '2013'}] ]

# %%
new_lists = []
from pprint import pprint
for a in lists:
    new_a = []
    used = []
    # print(len(a))
    for i in range(len(au_to_del)):
        if aa not in used:
            new_a.append(aa)
            used.append(aa)
        for aa in a:
            if [aa['author'], aa['name']] is in au_to_del and au_to_del[i][1] != 0 and aa not in used:
                print([aa['author'], aa['name']])
                new_a.append(aa)
                au_to_del[i][1] == 0
        new_lists.append(new_a)
pprint(new_lists)
# Out:
#   File "<ipython-input-84-c8c48a47b4a9>", line 12
#     if [aa['author'], aa['name']] is in au_to_del[i][0] and au_to_del[i][1] != 0 and aa not in used:
#                                       ^
# SyntaxError: invalid syntax

# %%
print(a)
# Out:
# [{'author': 'Кинг Стивен', 'name': 'Мобильник', 'genre': 'Художественная литература', 'year': '2013'}]

# %%
au_to_del[0][1] = 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-eddfd041e5a2> in <module>()
# ----> 1 au_to_del[0][1] = 2
#
# TypeError: 'tuple' object does not support item assignment
